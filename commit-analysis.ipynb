# %% [markdown]
# ### Importing libraries

# %%
import os
import git
from shutil import rmtree
from pydriller import RepositoryMining
from xml.etree import ElementTree
from matplotlib import pyplot as plt

# %% [markdown]
# ### Defining global variables

# %%
REPOSITORIES_FOLDER = "data/"

# %% [markdown]
# ### Defining utilitties functions

# %%
def get_projects(projects_list: list):
    projects_paths = list()

    for project in projects_list:
        print(f"Cloning repository {project}")

        path = REPOSITORIES_FOLDER + project.split("/")[-1]
        if not os.path.exists(path):
            git.Git(REPOSITORIES_FOLDER).clone(f"{project}")

        print("Checking if the project contains pom file ...")

        if not contains_pom_file(path):
            print(f"Removing {path}")
            rmtree(path)
        else:
            projects_paths.append(path)

    return projects_paths

# %%
def contains_pom_file(project_path: str):
    for root, folders, files in os.walk(project_path):
        if files.count('pom.xml'):
            return True
    return False

# %%
def extract_dependencies(source_code: str):
    dependencies = list()
    tree = ElementTree.fromstring(source_code)

    # Analyze properties of the POM file
    for child in tree:
        child_tag = child.tag
        child_tag = child_tag.split('}')[-1]

        if child_tag == "dependencies":
            for dependency in child:
                dependency_sentence = ''

                for attribute in dependency:
                    dependency_sentence += attribute.text + "|"

                dependencies.append(dependency_sentence[:-1])

    return set(dependencies)

# %%
def analyze_code(source_code: str):
    if source_code:
        source = source_code.split('\n')
        cleaned_lines = [line.strip() for line in source]
        source = '\n'.join(cleaned_lines)

        return extract_dependencies(source)

# %%
def pom_analysis(project_path: str):
    lengths_dependencies = list()
    k = 0

    for commit in RepositoryMining(project_path).traverse_commits():
        k += 1
        print(f"{k} - ANOTHER COMMIT")

        for modification in commit.modifications:
            if modification.filename == 'pom.xml':
                dependencies = analyze_code(modification.source_code)
                print(dependencies, end=" ")
        print()

    return lengths_dependencies

# %% [markdown]
# ### Checking projects

# %%
# projects = list()
#
# with open(f'{REPOSITORIES_FOLDER}/repositories.txt') as f:
#     while True:
#         line = f.readline()
#         if not line:
#             break
#         else:
#             line = line.strip()
#             projects.append(line)
#
# projects_paths = get_projects(projects)
#
# with open(f'{REPOSITORIES_FOLDER}/remaining.txt', 'w') as f:
#     for path in projects_paths:
#         f.writelines(path + "\n")

projects_poms = list()

with open(f'{REPOSITORIES_FOLDER}/remaining.txt') as f:
    while True:
        line = f.readline()
        if not line:
            break
        else:
            line = line.strip()
            projects_poms.append(line)

pom_analysis(projects_poms[0])
# Out:
# 1 - ANOTHER COMMIT
#
# 2 - ANOTHER COMMIT
#
# 3 - ANOTHER COMMIT
# set()
# 4 - ANOTHER COMMIT
# set()
# 5 - ANOTHER COMMIT
# set()
# 6 - ANOTHER COMMIT
# set()
# 7 - ANOTHER COMMIT
# set()
# 8 - ANOTHER COMMIT
#
# 9 - ANOTHER COMMIT
# set()
# 10 - ANOTHER COMMIT
# set()
# 11 - ANOTHER COMMIT
# set()
# 12 - ANOTHER COMMIT
#
# 13 - ANOTHER COMMIT
# set()
# 14 - ANOTHER COMMIT
# set()
# 15 - ANOTHER COMMIT
# {'junit|junit|4.8.1|test'}
# 16 - ANOTHER COMMIT
#
# 17 - ANOTHER COMMIT
# {'junit|junit|4.8.1|test'}
# 18 - ANOTHER COMMIT
# {'junit|junit|4.8.1|test'}
# 19 - ANOTHER COMMIT
# {'junit|junit|4.8.1|test'}
# 20 - ANOTHER COMMIT
#
# 21 - ANOTHER COMMIT
# {'junit|junit|4.8.1|test'}
# 22 - ANOTHER COMMIT
# {'junit|junit|4.8.1|test'}
# 23 - ANOTHER COMMIT
#
# 24 - ANOTHER COMMIT
# {'junit|junit|4.8.1|test'}
# 25 - ANOTHER COMMIT
# {'junit|junit|4.8.1|test'}
# 26 - ANOTHER COMMIT
# {'junit|junit|4.8.1|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'org.mockito|mockito-core|1.8.5|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test'}
# 27 - ANOTHER COMMIT
#
# 28 - ANOTHER COMMIT
# {'junit|junit|4.8.1|test'}
# 29 - ANOTHER COMMIT
# {'junit|junit|4.8.1|test'}
# 30 - ANOTHER COMMIT
#
# 31 - ANOTHER COMMIT
#
# 32 - ANOTHER COMMIT
# {'junit|junit|4.8.1|test'}
# 33 - ANOTHER COMMIT
# {'junit|junit|4.8.1|test'}
# 34 - ANOTHER COMMIT
# {'junit|junit|4.8.1|test'}
# 35 - ANOTHER COMMIT
# {'junit|junit|4.8.1|test'}
# 36 - ANOTHER COMMIT
# {'junit|junit|4.8.1|test'}
# 37 - ANOTHER COMMIT
#
# 38 - ANOTHER COMMIT
#
# 39 - ANOTHER COMMIT
#
# 40 - ANOTHER COMMIT
#
# 41 - ANOTHER COMMIT
#
# 42 - ANOTHER COMMIT
#
# 43 - ANOTHER COMMIT
#
# 44 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'org.hamcrest|hamcrest-all|1.3|test'}
# 45 - ANOTHER COMMIT
#
# 46 - ANOTHER COMMIT
#
# 47 - ANOTHER COMMIT
#
# 48 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'org.hamcrest|hamcrest-all|1.3|test'}
# 49 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'org.hamcrest|hamcrest-all|1.3|test'}
# 50 - ANOTHER COMMIT
#
# 51 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'org.hamcrest|hamcrest-all|1.3|test'}
# 52 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'org.hamcrest|hamcrest-all|1.3|test'}
# 53 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'nl.jqno.equalsverifier|equalsverifier|1.1.3', 'org.hamcrest|hamcrest-all|1.3|test', 'org.mockito|mockito-all|1.9.0|test'}
# 54 - ANOTHER COMMIT
#
# 55 - ANOTHER COMMIT
#
# 56 - ANOTHER COMMIT
#
# 57 - ANOTHER COMMIT
#
# 58 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'nl.jqno.equalsverifier|equalsverifier|1.1.3', 'org.hamcrest|hamcrest-all|1.3|test', 'org.mockito|mockito-all|1.9.0|test'}
# 59 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'nl.jqno.equalsverifier|equalsverifier|1.1.3', 'org.hamcrest|hamcrest-all|1.3|test', 'org.mockito|mockito-all|1.9.0|test'}
# 60 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'nl.jqno.equalsverifier|equalsverifier|1.1.3', 'org.hamcrest|hamcrest-all|1.3|test', 'org.mockito|mockito-all|1.9.0|test'}
# 61 - ANOTHER COMMIT
#
# 62 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'org.hamcrest|hamcrest-all|1.3|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.1.3', 'org.powermock|powermock-module-junit4-rule-agent|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.0|test'}
# 63 - ANOTHER COMMIT
#
# 64 - ANOTHER COMMIT
#
# 65 - ANOTHER COMMIT
#
# 66 - ANOTHER COMMIT
#
# 67 - ANOTHER COMMIT
#
# 68 - ANOTHER COMMIT
#
# 69 - ANOTHER COMMIT
#
# 70 - ANOTHER COMMIT
#
# 71 - ANOTHER COMMIT
#
# 72 - ANOTHER COMMIT
#
# 73 - ANOTHER COMMIT
#
# 74 - ANOTHER COMMIT
#
# 75 - ANOTHER COMMIT
#
# 76 - ANOTHER COMMIT
#
# 77 - ANOTHER COMMIT
#
# 78 - ANOTHER COMMIT
#
# 79 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'org.hamcrest|hamcrest-all|1.3|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.1.3', 'org.powermock|powermock-module-junit4-rule-agent|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.0|test'}
# 80 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'org.hamcrest|hamcrest-all|1.3|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.1.3', 'org.powermock|powermock-module-junit4-rule-agent|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.0|test'}
# 81 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'org.hamcrest|hamcrest-all|1.3|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.1.3', 'org.powermock|powermock-module-junit4-rule-agent|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.0|test'}
# 82 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'org.hamcrest|hamcrest-all|1.3|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.1.3', 'org.powermock|powermock-module-junit4-rule-agent|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.0|test'}
# 83 - ANOTHER COMMIT
#
# 84 - ANOTHER COMMIT
#
# 85 - ANOTHER COMMIT
#
# 86 - ANOTHER COMMIT
#
# 87 - ANOTHER COMMIT
#
# 88 - ANOTHER COMMIT
#
# 89 - ANOTHER COMMIT
#
# 90 - ANOTHER COMMIT
#
# 91 - ANOTHER COMMIT
#
# 92 - ANOTHER COMMIT
#
# 93 - ANOTHER COMMIT
#
# 94 - ANOTHER COMMIT
#
# 95 - ANOTHER COMMIT
#
# 96 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'org.hamcrest|hamcrest-all|1.3|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.1.3', 'org.powermock|powermock-module-junit4-rule-agent|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.0|test'}
# 97 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'org.hamcrest|hamcrest-all|1.3|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.1.3', 'org.powermock|powermock-module-junit4-rule-agent|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.0|test'}
# 98 - ANOTHER COMMIT
#
# 99 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'org.hamcrest|hamcrest-all|1.3|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.1.3', 'org.powermock|powermock-module-junit4-rule-agent|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.0|test'}
# 100 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'org.hamcrest|hamcrest-all|1.3|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.1.3', 'org.powermock|powermock-module-junit4-rule-agent|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.0|test'}
# 101 - ANOTHER COMMIT
#
# 102 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'org.hamcrest|hamcrest-all|1.3|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.1.3', 'org.powermock|powermock-module-junit4-rule-agent|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.0|test'}
# 103 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'org.hamcrest|hamcrest-all|1.3|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.1.3', 'org.powermock|powermock-module-junit4-rule-agent|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.0|test'}
# 104 - ANOTHER COMMIT
#
# 105 - ANOTHER COMMIT
#
# 106 - ANOTHER COMMIT
#
# 107 - ANOTHER COMMIT
#
# 108 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'org.hamcrest|hamcrest-all|1.3|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.1.3', 'org.powermock|powermock-module-junit4-rule-agent|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.0|test'}
# 109 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'org.hamcrest|hamcrest-all|1.3|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.1.3', 'org.powermock|powermock-module-junit4-rule-agent|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.0|test'}
# 110 - ANOTHER COMMIT
#
# 111 - ANOTHER COMMIT
#
# 112 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'org.hamcrest|hamcrest-all|1.3|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.1.3', 'org.powermock|powermock-module-junit4-rule-agent|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.0|test'}
# 113 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'org.hamcrest|hamcrest-all|1.3|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.1.3', 'org.powermock|powermock-module-junit4-rule-agent|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.0|test'}
# 114 - ANOTHER COMMIT
#
# 115 - ANOTHER COMMIT
#
# 116 - ANOTHER COMMIT
# {'junit|junit-dep|4.10|test', 'org.hamcrest|hamcrest-all|1.3|test', 'com.google.code.findbugs|jsr305|2.0.1|provided', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.1.3', 'org.powermock|powermock-module-junit4-rule-agent|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.0|test'}
# 117 - ANOTHER COMMIT
#
# 118 - ANOTHER COMMIT
#
# 119 - ANOTHER COMMIT
#
# 120 - ANOTHER COMMIT
# {'nl.jqno.equalsverifier|equalsverifier|1.1.3|test', 'junit|junit-dep|4.10|test', 'org.hamcrest|hamcrest-all|1.3|test', 'com.google.code.findbugs|jsr305|2.0.1|provided', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'org.powermock|powermock-module-junit4-rule-agent|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.0|test'}
# 121 - ANOTHER COMMIT
#
# 122 - ANOTHER COMMIT
# {'org.hamcrest|hamcrest-all|1.3|test', 'nl.jqno.equalsverifier|equalsverifier|1.3.1|test', 'com.google.code.findbugs|jsr305|2.0.1|provided', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'org.powermock|powermock-module-junit4-rule-agent|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test'}
# 123 - ANOTHER COMMIT
# {'org.hamcrest|hamcrest-all|1.3|test', 'nl.jqno.equalsverifier|equalsverifier|1.3.1|test', 'com.google.code.findbugs|jsr305|2.0.1|provided', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'org.powermock|powermock-module-junit4-rule-agent|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test'}
# 124 - ANOTHER COMMIT
# {'org.hamcrest|hamcrest-all|1.3|test', 'nl.jqno.equalsverifier|equalsverifier|1.3.1|test', 'com.google.code.findbugs|jsr305|2.0.1|provided', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'org.powermock|powermock-module-junit4-rule-agent|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test'}
# 125 - ANOTHER COMMIT
#
# 126 - ANOTHER COMMIT
#
# 127 - ANOTHER COMMIT
#
# 128 - ANOTHER COMMIT
# {'org.hamcrest|hamcrest-all|1.3|test', 'nl.jqno.equalsverifier|equalsverifier|1.3.1|test', 'com.google.code.findbugs|jsr305|2.0.1|provided', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'org.powermock|powermock-module-junit4-rule-agent|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test'}
# 129 - ANOTHER COMMIT
# {'org.hamcrest|hamcrest-all|1.3|test', 'nl.jqno.equalsverifier|equalsverifier|1.3.1|test', 'com.google.code.findbugs|jsr305|2.0.1|provided', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'org.powermock|powermock-module-junit4-rule-agent|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test'}
# 130 - ANOTHER COMMIT
#
# 131 - ANOTHER COMMIT
# {'org.hamcrest|hamcrest-all|1.3|test', 'nl.jqno.equalsverifier|equalsverifier|1.3.1|test', 'com.google.code.findbugs|jsr305|2.0.1|provided', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'org.powermock|powermock-module-junit4-rule-agent|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test'}
# 132 - ANOTHER COMMIT
# {'org.hamcrest|hamcrest-all|1.3|test', 'nl.jqno.equalsverifier|equalsverifier|1.3.1|test', 'com.google.code.findbugs|jsr305|2.0.1|provided', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'org.powermock|powermock-module-junit4-rule-agent|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test'}
# 133 - ANOTHER COMMIT
#
# 134 - ANOTHER COMMIT
#
# 135 - ANOTHER COMMIT
#
# 136 - ANOTHER COMMIT
#
# 137 - ANOTHER COMMIT
#
# 138 - ANOTHER COMMIT
#
# 139 - ANOTHER COMMIT
#
# 140 - ANOTHER COMMIT
#
# 141 - ANOTHER COMMIT
#
# 142 - ANOTHER COMMIT
#
# 143 - ANOTHER COMMIT
#
# 144 - ANOTHER COMMIT
#
# 145 - ANOTHER COMMIT
#
# 146 - ANOTHER COMMIT
#
# 147 - ANOTHER COMMIT
#
# 148 - ANOTHER COMMIT
#
# 149 - ANOTHER COMMIT
#
# 150 - ANOTHER COMMIT
#
# 151 - ANOTHER COMMIT
# {'org.hamcrest|hamcrest-all|1.3|test', 'nl.jqno.equalsverifier|equalsverifier|1.3.1|test', 'com.google.code.findbugs|jsr305|2.0.1|provided', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test'}
# 152 - ANOTHER COMMIT
#
# 153 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.3.1|test', 'com.google.code.findbugs|jsr305|2.0.1|provided', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 154 - ANOTHER COMMIT
#
# 155 - ANOTHER COMMIT
#
# 156 - ANOTHER COMMIT
#
# 157 - ANOTHER COMMIT
#
# 158 - ANOTHER COMMIT
#
# 159 - ANOTHER COMMIT
#
# 160 - ANOTHER COMMIT
#
# 161 - ANOTHER COMMIT
#
# 162 - ANOTHER COMMIT
#
# 163 - ANOTHER COMMIT
#
# 164 - ANOTHER COMMIT
#
# 165 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.3.1|test', 'com.google.code.findbugs|jsr305|2.0.1|provided', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 166 - ANOTHER COMMIT
# {'com.google.code.findbugs|jsr305|2.0.2|provided', 'org.powermock|powermock-core|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.3.1|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 167 - ANOTHER COMMIT
#
# 168 - ANOTHER COMMIT
#
# 169 - ANOTHER COMMIT
#
# 170 - ANOTHER COMMIT
#
# 171 - ANOTHER COMMIT
#
# 172 - ANOTHER COMMIT
#
# 173 - ANOTHER COMMIT
# {'com.google.code.findbugs|jsr305|2.0.2|provided', 'org.powermock|powermock-core|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.3.1|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 174 - ANOTHER COMMIT
#
# 175 - ANOTHER COMMIT
#
# 176 - ANOTHER COMMIT
#
# 177 - ANOTHER COMMIT
#
# 178 - ANOTHER COMMIT
#
# 179 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|jsr305|2.0.3|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.4|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 180 - ANOTHER COMMIT
#
# 181 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|jsr305|2.0.3|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.4|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 182 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|jsr305|2.0.3|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.4|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 183 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|jsr305|2.0.3|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.4|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 184 - ANOTHER COMMIT
#
# 185 - ANOTHER COMMIT
#
# 186 - ANOTHER COMMIT
#
# 187 - ANOTHER COMMIT
#
# 188 - ANOTHER COMMIT
#
# 189 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|jsr305|2.0.3|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.4|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 190 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|jsr305|2.0.3|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.4|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 191 - ANOTHER COMMIT
#
# 192 - ANOTHER COMMIT
#
# 193 - ANOTHER COMMIT
#
# 194 - ANOTHER COMMIT
#
# 195 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|jsr305|2.0.3|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.4|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 196 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|jsr305|2.0.3|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.4|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 197 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|jsr305|2.0.3|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.4|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 198 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|jsr305|2.0.3|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.4|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 199 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|jsr305|2.0.3|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.4|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 200 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|jsr305|2.0.3|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.4|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 201 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|jsr305|2.0.3|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.4|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 202 - ANOTHER COMMIT
#
# 203 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|jsr305|2.0.3|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.4.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 204 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|jsr305|2.0.3|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.4.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 205 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|jsr305|2.0.3|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.4.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 206 - ANOTHER COMMIT
#
# 207 - ANOTHER COMMIT
#
# 208 - ANOTHER COMMIT
#
# 209 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|jsr305|2.0.3|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.4.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 210 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|jsr305|2.0.3|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.4.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 211 - ANOTHER COMMIT
#
# 212 - ANOTHER COMMIT
#
# 213 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'com.google.code.findbugs|annotations|2.0.3|provided', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.4.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 214 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'com.google.code.findbugs|annotations|2.0.3|provided', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.4.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 215 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'com.google.code.findbugs|annotations|2.0.3|provided', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.4.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 216 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'com.google.code.findbugs|annotations|2.0.3|provided', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.4.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 217 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.5.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 218 - ANOTHER COMMIT
#
# 219 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.5.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 220 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.5.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 221 - ANOTHER COMMIT
#
# 222 - ANOTHER COMMIT
#
# 223 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.5.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 224 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.5.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 225 - ANOTHER COMMIT
#
# 226 - ANOTHER COMMIT
#
# 227 - ANOTHER COMMIT
#
# 228 - ANOTHER COMMIT
#
# 229 - ANOTHER COMMIT
#
# 230 - ANOTHER COMMIT
#
# 231 - ANOTHER COMMIT
#
# 232 - ANOTHER COMMIT
# 233 - ANOTHER COMMIT
#
# 234 - ANOTHER COMMIT
#
# 235 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.5.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 236 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.5.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 237 - ANOTHER COMMIT
# {'org.jenkins-ci.main|jenkins-core|1.608-20150331.155258-2|provided', 'org.jenkins-ci.plugins.workflow|workflow-job|1.5-20150331.150925-6|test', 'org.jenkins-ci.plugins.workflow|workflow-step-api|1.5-20150331.145606-6|tests|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.jenkins-ci.plugins.workflow|workflow-cps|1.5-20150331.150709-6|test', 'org.jenkins-ci.main|jenkins-war|1.608-20150331.155326-2|war-for-test|test', 'org.powermock|powermock-core|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test', 'org.jenkins-ci.plugins.workflow|workflow-basic-steps|1.5-20150331.150304-6|test', 'org.jenkins-ci.plugins.workflow|workflow-durable-task-step|1.5-20150331.150349-6|test', 'org.mockito|mockito-all|1.9.5|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.5.1|test', 'org.jenkins-ci.plugins.workflow|workflow-support|1.5-20150331.150001-6|tests|test', 'org.jenkins-ci.main|jenkins-war|1.608-20150331.155326-2|war|test'}
# 238 - ANOTHER COMMIT
#
# 239 - ANOTHER COMMIT
# {'org.jenkins-ci.main|jenkins-core|1.608-20150331.155258-2|provided', 'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.5.1|test', 'org.jenkins-ci.main|jenkins-war|1.608-20150331.155326-2|war-for-test|test', 'org.jenkins-ci.main|jenkins-war|1.608-20150331.155326-2|war|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 240 - ANOTHER COMMIT
#
# 241 - ANOTHER COMMIT
#
# 242 - ANOTHER COMMIT
#
# 243 - ANOTHER COMMIT
#
# 244 - ANOTHER COMMIT
#
# 245 - ANOTHER COMMIT
#
# 246 - ANOTHER COMMIT
#
# 247 - ANOTHER COMMIT
#
# 248 - ANOTHER COMMIT
#
# 249 - ANOTHER COMMIT
#
# 250 - ANOTHER COMMIT
#
# 251 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.5.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 252 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.5.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 253 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.5.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 254 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.5.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 255 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.5.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 256 - ANOTHER COMMIT
#
# 257 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.5.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 258 - ANOTHER COMMIT
#
# 259 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.5.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 260 - ANOTHER COMMIT
#
# 261 - ANOTHER COMMIT
#
# 262 - ANOTHER COMMIT
#
# 263 - ANOTHER COMMIT
#
# 264 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.5.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 265 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'junit|junit|4.11|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.mockito|mockito-all|1.9.5|test', 'nl.jqno.equalsverifier|equalsverifier|1.5.1|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 266 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.7.2|test', 'org.mockito|mockito-all|1.10.19|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'junit|junit|4.12|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 267 - ANOTHER COMMIT
#
# 268 - ANOTHER COMMIT
#
# 269 - ANOTHER COMMIT
#
# 270 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.7.2|test', 'org.mockito|mockito-all|1.10.19|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'junit|junit|4.12|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 271 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.7.2|test', 'org.mockito|mockito-all|1.10.19|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'junit|junit|4.12|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 272 - ANOTHER COMMIT
#
# 273 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.7.2|test', 'org.mockito|mockito-all|1.10.19|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'junit|junit|4.12|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 274 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.7.2|test', 'org.mockito|mockito-all|1.10.19|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'junit|junit|4.12|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 275 - ANOTHER COMMIT
#
# 276 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.7.2|test', 'org.mockito|mockito-all|1.10.19|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'junit|junit|4.12|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 277 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.7.2|test', 'org.mockito|mockito-all|1.10.19|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'junit|junit|4.12|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 278 - ANOTHER COMMIT
#
# 279 - ANOTHER COMMIT
#
# 280 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.7.2|test', 'org.mockito|mockito-all|1.10.19|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'junit|junit|4.12|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 281 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.7.2|test', 'org.mockito|mockito-all|1.10.19|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'com.google.code.findbugs|annotations|3.0.0|provided', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'junit|junit|4.12|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 282 - ANOTHER COMMIT
#
# 283 - ANOTHER COMMIT
#
# 284 - ANOTHER COMMIT
#
# 285 - ANOTHER COMMIT
#
# 286 - ANOTHER COMMIT
#
# 287 - ANOTHER COMMIT
#
# 288 - ANOTHER COMMIT
#
# 289 - ANOTHER COMMIT
#
# 290 - ANOTHER COMMIT
#
# 291 - ANOTHER COMMIT
#
# 292 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'nl.jqno.equalsverifier|equalsverifier|1.7.2|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 293 - ANOTHER COMMIT
# {'org.powermock|powermock-core|${powermock.version}|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'nl.jqno.equalsverifier|equalsverifier|1.7.7|test', 'org.powermock|powermock-module-junit4|${powermock.version}|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|${powermock.version}|test', 'org.powermock|powermock-api-mockito|${powermock.version}|test', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 294 - ANOTHER COMMIT
#
# 295 - ANOTHER COMMIT
#
# 296 - ANOTHER COMMIT
#
# 297 - ANOTHER COMMIT
#
# 298 - ANOTHER COMMIT
#
# 299 - ANOTHER COMMIT
#
# 300 - ANOTHER COMMIT
#
# 301 - ANOTHER COMMIT
#
# 302 - ANOTHER COMMIT
#
# 303 - ANOTHER COMMIT
#
# 304 - ANOTHER COMMIT
#
# 305 - ANOTHER COMMIT
#
# 306 - ANOTHER COMMIT
#
# 307 - ANOTHER COMMIT
#
# 308 - ANOTHER COMMIT
#
# 309 - ANOTHER COMMIT
#
# 310 - ANOTHER COMMIT
#
# ...
# 349 - ANOTHER COMMIT
# {'nl.jqno.equalsverifier|equalsverifier|1.7.8|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.powermock|powermock-reflect|1.6.5|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.jenkins-ci.plugins.workflow|workflow-step-api|1.7|true', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 350 - ANOTHER COMMIT
# 351 - ANOTHER COMMIT
#
# 352 - ANOTHER COMMIT
#
# 353 - ANOTHER COMMIT
# {'nl.jqno.equalsverifier|equalsverifier|1.7.8|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.powermock|powermock-reflect|1.6.5|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.jenkins-ci.plugins.workflow|workflow-step-api|1.7|true', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 354 - ANOTHER COMMIT
# {'nl.jqno.equalsverifier|equalsverifier|1.7.8|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.powermock|powermock-reflect|1.6.5|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.jenkins-ci.plugins.workflow|workflow-step-api|1.7|true', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 355 - ANOTHER COMMIT
# {'nl.jqno.equalsverifier|equalsverifier|1.7.8|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.powermock|powermock-reflect|1.6.5|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.jenkins-ci.plugins.workflow|workflow-step-api|1.7|true', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 356 - ANOTHER COMMIT
#
# 357 - ANOTHER COMMIT
#
# 358 - ANOTHER COMMIT
#
# 359 - ANOTHER COMMIT
#
# 360 - ANOTHER COMMIT
#
# 361 - ANOTHER COMMIT
#
# 362 - ANOTHER COMMIT
#
# 363 - ANOTHER COMMIT
#
# 364 - ANOTHER COMMIT
#
# 365 - ANOTHER COMMIT
#
# 366 - ANOTHER COMMIT
# {'nl.jqno.equalsverifier|equalsverifier|1.7.8|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.powermock|powermock-reflect|1.6.5|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.jenkins-ci.plugins.workflow|workflow-step-api|1.7|true', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 367 - ANOTHER COMMIT
# {'nl.jqno.equalsverifier|equalsverifier|1.7.8|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.powermock|powermock-reflect|1.6.5|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.jenkins-ci.plugins.workflow|workflow-step-api|1.7|true', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 368 - ANOTHER COMMIT
#
# 369 - ANOTHER COMMIT
#
# 370 - ANOTHER COMMIT
#
# 371 - ANOTHER COMMIT
# {'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.powermock|powermock-reflect|1.6.5|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'nl.jqno.equalsverifier|equalsverifier|2.1.5|test', 'org.jenkins-ci.plugins.workflow|workflow-step-api|1.7|true', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 372 - ANOTHER COMMIT
#
# 373 - ANOTHER COMMIT
#
# 374 - ANOTHER COMMIT
#
# 375 - ANOTHER COMMIT
# {'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.powermock|powermock-reflect|1.6.5|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'nl.jqno.equalsverifier|equalsverifier|2.1.5|test', 'org.jenkins-ci.plugins.workflow|workflow-step-api|1.7|true', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 376 - ANOTHER COMMIT
#
# 377 - ANOTHER COMMIT
# {'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.powermock|powermock-reflect|1.6.5|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'nl.jqno.equalsverifier|equalsverifier|2.1.5|test', 'org.jenkins-ci.plugins.workflow|workflow-step-api|1.7|true', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 378 - ANOTHER COMMIT
# {'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.powermock|powermock-reflect|1.6.5|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'nl.jqno.equalsverifier|equalsverifier|2.1.5|test', 'org.jenkins-ci.plugins.workflow|workflow-step-api|1.7|true', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 379 - ANOTHER COMMIT
#
# 380 - ANOTHER COMMIT
# {'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.powermock|powermock-reflect|1.6.5|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'nl.jqno.equalsverifier|equalsverifier|2.1.5|test', 'org.jenkins-ci.plugins.workflow|workflow-step-api|1.7|true', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 381 - ANOTHER COMMIT
# {'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.powermock|powermock-reflect|1.6.5|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'nl.jqno.equalsverifier|equalsverifier|2.1.5|test', 'org.jenkins-ci.plugins.workflow|workflow-step-api|1.7|true', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 382 - ANOTHER COMMIT
#
# 383 - ANOTHER COMMIT
#
# 384 - ANOTHER COMMIT
#
# 385 - ANOTHER COMMIT
#
# 386 - ANOTHER COMMIT
#
# 387 - ANOTHER COMMIT
#
# 388 - ANOTHER COMMIT
# {'nl.jqno.equalsverifier|equalsverifier|2.2|test', 'org.powermock|powermock-reflect|1.6.6|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.jenkins-ci.plugins.workflow|workflow-step-api|1.7|true', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 389 - ANOTHER COMMIT
# {'nl.jqno.equalsverifier|equalsverifier|2.2|test', 'org.powermock|powermock-reflect|1.6.6|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.jenkins-ci.plugins.workflow|workflow-step-api|1.7|true', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 390 - ANOTHER COMMIT
# {'nl.jqno.equalsverifier|equalsverifier|2.2|test', 'org.powermock|powermock-reflect|1.6.6|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.jenkins-ci.plugins.workflow|workflow-step-api|1.7|true', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 391 - ANOTHER COMMIT
#
# 392 - ANOTHER COMMIT
# {'nl.jqno.equalsverifier|equalsverifier|2.4|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|1.7.3|test', 'org.jenkins-ci.plugins.workflow|workflow-step-api|1.7|true', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 393 - ANOTHER COMMIT
#
# 394 - ANOTHER COMMIT
#
# 395 - ANOTHER COMMIT
#
# 396 - ANOTHER COMMIT
#
# 397 - ANOTHER COMMIT
# {'nl.jqno.equalsverifier|equalsverifier|2.4|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|1.7.3|test', 'org.jenkins-ci.plugins.workflow|workflow-step-api|1.7|true', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 398 - ANOTHER COMMIT
# {'nl.jqno.equalsverifier|equalsverifier|2.4|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.hamcrest|hamcrest-library|${hamcrest.version}|test', 'org.powermock|powermock-reflect|1.7.3|test', 'org.jenkins-ci.plugins.workflow|workflow-step-api|1.7|true', 'org.hamcrest|hamcrest-core|${hamcrest.version}|test'}
# 399 - ANOTHER COMMIT
#
# 400 - ANOTHER COMMIT
#
# 401 - ANOTHER COMMIT
#
# 402 - ANOTHER COMMIT
#
# 403 - ANOTHER COMMIT
#
# 404 - ANOTHER COMMIT
#
# 405 - ANOTHER COMMIT
#
# 406 - ANOTHER COMMIT
#
# 407 - ANOTHER COMMIT
#
# 408 - ANOTHER COMMIT
# {'org.hamcrest|hamcrest-library|1.3|test', 'nl.jqno.equalsverifier|equalsverifier|2.4.6|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.powermock|powermock-reflect|1.7.4|test', 'org.hamcrest|hamcrest-core|1.3|test', 'org.jenkins-ci.plugins.workflow|workflow-step-api|1.7|true'}
# 409 - ANOTHER COMMIT
#
# 410 - ANOTHER COMMIT
# {'org.hamcrest|hamcrest-library|1.3|test', 'nl.jqno.equalsverifier|equalsverifier|2.4.6|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.powermock|powermock-reflect|1.7.4|test', 'org.hamcrest|hamcrest-core|1.3|test', 'org.jenkins-ci.plugins.workflow|workflow-step-api|1.7|true'}
# 411 - ANOTHER COMMIT
# {'org.hamcrest|hamcrest-library|1.3|test', 'nl.jqno.equalsverifier|equalsverifier|2.4.6|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.powermock|powermock-reflect|1.7.4|test', 'org.hamcrest|hamcrest-core|1.3|test', 'org.jenkins-ci.plugins.workflow|workflow-step-api|1.7|true'}
# 412 - ANOTHER COMMIT
#
# 413 - ANOTHER COMMIT
#
# 414 - ANOTHER COMMIT
#
# 415 - ANOTHER COMMIT
# {'org.jenkins-ci.plugins.workflow|workflow-step-api|2.16', 'org.jenkins-ci.plugins.workflow|workflow-api|2.30-rc828.7aa7627c85df', 'org.hamcrest|hamcrest-library|1.3|test', 'nl.jqno.equalsverifier|equalsverifier|2.4.6|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.powermock|powermock-reflect|1.7.4|test', 'org.jenkins-ci.plugins.workflow|workflow-job|2.26-rc850.755e848ee6f8|test', 'org.jenkins-ci.plugins.workflow|workflow-cps|2.56|test', 'org.jenkins-ci.plugins.workflow|workflow-durable-task-step|2.22|test', 'org.hamcrest|hamcrest-core|1.3|test'}
# 416 - ANOTHER COMMIT
# {'org.jenkins-ci.plugins.workflow|workflow-step-api|2.16', 'org.hamcrest|hamcrest-library|1.3|test', 'nl.jqno.equalsverifier|equalsverifier|2.4.6|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.powermock|powermock-reflect|1.7.4|test', 'org.jenkins-ci.plugins.workflow|workflow-durable-task-step|2.22|test', 'org.jenkins-ci.plugins.workflow|workflow-api|2.30-beta-1', 'org.jenkins-ci.plugins.workflow|workflow-job|2.26-beta-1|test', 'org.hamcrest|hamcrest-core|1.3|test', 'org.jenkins-ci.plugins.workflow|workflow-cps|2.58-beta-1|test'}
# 417 - ANOTHER COMMIT
# 418 - ANOTHER COMMIT
#
# 419 - ANOTHER COMMIT
#
# 420 - ANOTHER COMMIT
#
# 421 - ANOTHER COMMIT
# {'org.jenkins-ci.plugins.workflow|workflow-step-api|2.16', 'org.hamcrest|hamcrest-library|1.3|test', 'nl.jqno.equalsverifier|equalsverifier|2.4.6|test', 'org.jenkins-ci.plugins.workflow|workflow-api|2.30', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins.workflow|workflow-cps|2.58|test', 'org.powermock|powermock-reflect|1.7.4|test', 'org.jenkins-ci.plugins.workflow|workflow-job|2.26|test', 'org.jenkins-ci.plugins.workflow|workflow-durable-task-step|2.22|test', 'org.hamcrest|hamcrest-core|1.3|test'}
# 422 - ANOTHER COMMIT
#
# 423 - ANOTHER COMMIT
#
# 424 - ANOTHER COMMIT
#
# 425 - ANOTHER COMMIT
#
# 426 - ANOTHER COMMIT
#
# 427 - ANOTHER COMMIT
#
# 428 - ANOTHER COMMIT
#
# 429 - ANOTHER COMMIT
#
# 430 - ANOTHER COMMIT
#
# 431 - ANOTHER COMMIT
#
# 432 - ANOTHER COMMIT
#
# 433 - ANOTHER COMMIT
#
# 434 - ANOTHER COMMIT
#
# 435 - ANOTHER COMMIT
# {'org.jenkins-ci.plugins.workflow|workflow-step-api|2.16', 'org.hamcrest|hamcrest-library|1.3|test', 'nl.jqno.equalsverifier|equalsverifier|2.4.6|test', 'org.jenkins-ci.plugins.workflow|workflow-api|2.30', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins.workflow|workflow-cps|2.58|test', 'org.powermock|powermock-reflect|1.7.4|test', 'org.jenkins-ci.plugins.workflow|workflow-job|2.26|test', 'org.jenkins-ci.plugins.workflow|workflow-durable-task-step|2.22|test', 'org.hamcrest|hamcrest-core|1.3|test'}
# 436 - ANOTHER COMMIT
# {'org.jenkins-ci.plugins.workflow|workflow-step-api|2.16', 'org.hamcrest|hamcrest-library|1.3|test', 'nl.jqno.equalsverifier|equalsverifier|2.4.6|test', 'org.jenkins-ci.plugins.workflow|workflow-api|2.30', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins.workflow|workflow-cps|2.58|test', 'org.powermock|powermock-reflect|1.7.4|test', 'org.jenkins-ci.plugins.workflow|workflow-job|2.26|test', 'org.jenkins-ci.plugins.workflow|workflow-durable-task-step|2.22|test', 'org.hamcrest|hamcrest-core|1.3|test'}
# 437 - ANOTHER COMMIT
# {'org.jenkins-ci.plugins.workflow|workflow-step-api|2.16', 'org.hamcrest|hamcrest-library|1.3|test', 'nl.jqno.equalsverifier|equalsverifier|2.4.6|test', 'org.jenkins-ci.plugins.workflow|workflow-api|2.30', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins.workflow|workflow-cps|2.58|test', 'org.powermock|powermock-reflect|1.7.4|test', 'org.jenkins-ci.plugins.workflow|workflow-job|2.26|test', 'org.jenkins-ci.plugins.workflow|workflow-durable-task-step|2.22|test', 'org.hamcrest|hamcrest-core|1.3|test'}
# 438 - ANOTHER COMMIT
#
# 439 - ANOTHER COMMIT
#
# 440 - ANOTHER COMMIT
#
# 441 - ANOTHER COMMIT
#
# 442 - ANOTHER COMMIT
# {'org.jenkins-ci.plugins.workflow|workflow-step-api|2.16', 'org.hamcrest|hamcrest-library|1.3|test', 'nl.jqno.equalsverifier|equalsverifier|2.4.6|test', 'org.jenkins-ci.plugins.workflow|workflow-api|2.30', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins.workflow|workflow-cps|2.58|test', 'org.powermock|powermock-reflect|1.7.4|test', 'org.jenkins-ci.plugins.workflow|workflow-job|2.26|test', 'org.jenkins-ci.plugins.workflow|workflow-basic-steps|2.12|test', 'org.jenkins-ci.plugins|ansicolor|0.5.3|test', 'org.jenkins-ci.plugins.workflow|workflow-durable-task-step|2.22|test', 'org.hamcrest|hamcrest-core|1.3|test'}
# 443 - ANOTHER COMMIT
#
# 444 - ANOTHER COMMIT
#
# 445 - ANOTHER COMMIT
# {'org.jenkins-ci.plugins.workflow|workflow-step-api|2.16', 'org.hamcrest|hamcrest-library|1.3|test', 'nl.jqno.equalsverifier|equalsverifier|2.4.6|test', 'org.jenkins-ci.plugins.workflow|workflow-api|2.30', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins.workflow|workflow-cps|2.58|test', 'org.powermock|powermock-reflect|1.7.4|test', 'org.jenkins-ci.plugins.workflow|workflow-job|2.26|test', 'org.jenkins-ci.plugins.workflow|workflow-basic-steps|2.12|test', 'org.jenkins-ci.plugins|ansicolor|0.6.2|test', 'org.jenkins-ci.plugins.workflow|workflow-durable-task-step|2.22|test', 'org.hamcrest|hamcrest-core|1.3|test'}
# 446 - ANOTHER COMMIT
#
# 447 - ANOTHER COMMIT
#
# 448 - ANOTHER COMMIT
#
# 449 - ANOTHER COMMIT
#
# 450 - ANOTHER COMMIT
# {'org.jenkins-ci.plugins.workflow|workflow-step-api|2.16', 'org.hamcrest|hamcrest-library|1.3|test', 'nl.jqno.equalsverifier|equalsverifier|2.4.6|test', 'org.jenkins-ci.plugins.workflow|workflow-api|2.30', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins.workflow|workflow-cps|2.58|test', 'org.powermock|powermock-reflect|1.7.4|test', 'org.jenkins-ci.plugins.workflow|workflow-job|2.26|test', 'org.jenkins-ci.plugins.workflow|workflow-basic-steps|2.12|test', 'org.jenkins-ci.plugins|ansicolor|0.6.2|test', 'org.jenkins-ci.plugins.workflow|workflow-durable-task-step|2.22|test', 'org.hamcrest|hamcrest-core|1.3|test'}
# 451 - ANOTHER COMMIT
# {'org.jenkins-ci.plugins.workflow|workflow-step-api|2.16', 'org.hamcrest|hamcrest-library|1.3|test', 'nl.jqno.equalsverifier|equalsverifier|2.4.6|test', 'org.jenkins-ci.plugins.workflow|workflow-api|2.30', 'org.jenkins-ci.plugins|ant|1.2|test', 'org.mockito|mockito-all|1.10.19|test', 'org.jenkins-ci.plugins.workflow|workflow-cps|2.58|test', 'org.powermock|powermock-reflect|1.7.4|test', 'org.jenkins-ci.plugins.workflow|workflow-job|2.26|test', 'org.jenkins-ci.plugins.workflow|workflow-basic-steps|2.12|test', 'org.jenkins-ci.plugins|ansicolor|0.6.2|test', 'org.jenkins-ci.plugins.workflow|workflow-durable-task-step|2.22|test', 'org.hamcrest|hamcrest-core|1.3|test'}
# 452 - ANOTHER COMMIT
# []
